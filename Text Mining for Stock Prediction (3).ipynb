# %% [markdown]
# # Text Mining for Stock Prediction

# %% [markdown]
# ## Data extraction:
#
#
# We should consolidate:
# * Publication date
# * Main extracts from the publication
# * Closing stock price before the publication
# * Opening stock price of day after the publication was filed
#
# To do:
# * Generalize 424B5 functions more.
# * Solve 8-K get_filing_documents problem.
#
# ## BERT
# Original repository: https://github.com/google-research/bert
#
# ### Pre-training
# * We have to determine the corpus on which we are going to pre-train BERT
# * We need separate sentences for the NSP task, and we need to tokenize the sentences for the MLM task (see https://github.com/google-research/bert/blob/master/create_pretraining_data.py)
# * See methodology section for detailed requirements.
#
# To do:
# * Mock-train BERT model to work through the data processing stage.
# * Pre-process training data
#
# ### Fine-tuning
# For fine-tuning Bert for our particular classification task, we are going to set-up an additional layer that is going to take in the text files and predicts whether the stock price of the company (should we denote which company filed what?) that filed a particular publication is going to increase, decrease or remain stable.
#
# #### Requirements:
# * Publication date
# * Sentences regarding the risk factors
# * Closing stock price before publication date
# * Opening stock price after publication date
# * Label (e.g. increase, decrease, stable)
#
# To do:
# * What is the format the training data should have?

# %% [markdown]
# ## Libraries

# %%
import requests
from bs4 import BeautifulSoup
from bs4 import NavigableString
from htmllaundry import sanitize
from htmllaundry.cleaners import LaundryCleaner
import htmllaundry.utils
import xmltodict
import re
import json
from pprint import pprint
import pandas as pd
from glob import glob
from cachecontrol import CacheControl
from IPython.display import HTML
import unicodedata
from bs4 import Comment

# %% [markdown]
#  # Scraping SEC filings

# %%
sess = requests.session()
cach = CacheControl(sess)

# %%
from IPython.display import HTML

def window(html):
    s = '<script type="text/javascript">'
    s += 'var win = window.open("", "", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + html.replace("\n",'\\n').replace("'", "\\'") + '\';'
    s += '</script>'
    return HTML(s)

# %% [markdown]
# ## Cleaning SEC encoding

# %%
CustomCleaner = LaundryCleaner(
            page_structure=False,
            remove_unknown_tags=False,
            allow_tags=['blockquote', 'a', 'i', 'em', 'p', 'b', 'strong',
                        'h1', 'h2', 'h3', 'h4', 'h5', 
                        'ul', 'ol', 'li', 
                        'sub', 'sup',
                        'abbr', 'acronym', 'dl', 'dt', 'dd', 'cite',
                        'dft', 'br', 
                        'table', 'tr', 'td', 'th', 'thead', 'tbody', 'tfoot'],
            safe_attrs_only=True,
            add_nofollow=True,
            scripts=True,
            javascript=True,
            comments=True,
            style=True,
            links=False,
            meta=True,
            processing_instructions=False,
            frames=True,
            annoying_tags=False)

# %%
## The SEC is encoded in CP1252, and it is recommended to use UTF-8 always.
##see: https://www.w3.org/International/questions/qa-what-is-encoding
###### https://www.w3.org/International/articles/definitions-characters/#unicode
###### https://www.w3.org/International/questions/qa-choosing-encodings

def reformat_cp1252(match):
    codePoint = int(match.group(1))
    if 128 <= codePoint <= 159:
        return bytes([codePoint])
    else:
        return match.group()

def clean_sec_content(binary):
    return re.sub(b'&#(\d+);', reformat_cp1252, binary, flags=re.I).decode("windows-1252").encode('utf-8').decode('utf-8')

# %%
## this is to normalize urls
def slugify(value):
    value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
    value = re.sub('[^\w\s\.\-]', '-', value).strip().lower()
    value = re.sub('[-\s]+', '-', value)
    return value

# %% [markdown]
# ## Cleaning html

# %%
def read_html(file):
    with open(file, 'r') as f: return f.read()

# %%
def clean_html(html):
    soup = BeautifulSoup(html)
    if not soup.find('p'):
        for div in soup.find_all('div'):
            div.name = 'p'
    for b in soup.find_all('b'):
        b.name = 'strong'
    for f in soup.find_all('font', style=re.compile('font-weight:\s*bold')):
        f.name = 'strong'
    for footer in soup.find_all(class_=['header', 'footer']): 
        try: footer.decompose()
        except: pass
    san = sanitize(str(soup), CustomCleaner)
    soup = BeautifulSoup(san)
    def decompose_parent(el, parent='p', not_grandparent='table'):
        try:
            parent = el.find_parent(parent)
        except: parent = None
        if not parent: return
        grandparent = parent.find_parent('table')
        if grandparent: return
        parent.decompose()
    for el in soup.find_all(text=lambda x: 'table of contents' == str(x).lower().strip()):
        decompose_parent(el, 'a')
    for el in soup.find_all(text=re.compile(r'^\s*S\-(\d+|[ivxlcdm]+)\s*$')): 
        decompose_parent(el, 'p')
    for el in soup.find_all(text=re.compile(r'^\s*\d+\s*$')): 
        decompose_parent(el, 'p')
    return soup

# %% [markdown]
# ## Defining helper functions to download files

# %%
def pagination_provider_by_element_start_count(find_args, find_kwargs):
    def pagination_provider_by_element_start_count_wrapped(soup, params):
        if soup.find(*find_args, **find_kwargs) is None: 
            return None
        params['start'] += params['count'] 
        return params
    return pagination_provider_by_element_start_count_wrapped

# %%
def params_provider_by_dict(params):
    return lambda : params

# %%
## look for a table, converts it to text and removes line breaks
def table_provider_by_summary(summary, header=0, index_col=0):
    return lambda soup: pd.read_html(
        str(soup.find('table', summary=summary)).replace('<br>', '<br>\n'), header=header, index_col=index_col)[0]

# %%
def get_sec_table(url,
                  table_provider=None,
                  base_params={}, 
                  params_provider=None,
                  pagination_provider=None,
                  replace_links=True,
                  session=None):
    ### this function returns a tuple of a df with the respective soup element
    def return_data_frame(session, url, params, provider):
        request = session.get(url, params=params)
        soup = BeautifulSoup(request.text)
        if replace_links:
            for a in soup.find_all('a'):
                parent = a.find_parent('td')
                if parent: parent.string = a['href']
        df = provider(soup)
        return df, soup
    ####################################################################
    ###if no Session, then we use the base_url to do the pull request###
    ####################################################################
    if session is None:
        session = cach
    if not url.startswith('http://') and not url.startswith('https://'):
        url = base_url.format(url)
    ###############################################################################################    
    ###if the specified parameters are a dictionary, update params with the specified parameters###
    ###############################################################################################
    params = dict(base_params)
    if params_provider:
        if isinstance(params_provider, dict):
            params.update(params_provider)
        else:
            params.update(params_provider())
    ### in case you only scrape one page, it will just return the df of the respective page###
    if not pagination_provider:
        df, soup = return_data_frame(session, url, params, table_provider)
        return df
    ### in case you want to scrape multiple pages, create an empty list of dfs and add each df from each 
    ### page to the empty list, at the end you just concatenate all of the dfs
    else:
        data_frames = []
        page_params = dict(params)
        while True:
            df, soup = return_data_frame(session, url, page_params, table_provider)
            data_frames.append(df)
            # Make sure columns retain their names
            data_frames[-1].columns = data_frames[0].columns
            new_params = pagination_provider(soup, page_params)
            if not new_params:
                break
            else:
                page_params.update(new_params)
        return pd.concat(data_frames, sort=False, ignore_index=True)

# %% [markdown]
# ## Function to get the documents

# %% [markdown]
# This is a function to get the documents in the filing details page for each filing. See below for an example page.

# %%
get_filing_documents = lambda url, summary = 'Document Format Files' : get_sec_table(url,
                                                                                    table_provider = table_provider_by_summary(summary, index_col=None),
                                                                                    pagination_provider = pagination_provider_by_element_start_count(('input',), {'value': 'Next 100'}))

# %% [markdown]
# ## Scraping most recent filings

# %% [markdown]
# For the previous 5 days

# %%
base_url = 'https://www.sec.gov{}'

# %%
def get_current_events(days_before=0, form_type=''):
    soup = BeautifulSoup(cach.get(base_url.format('/cgi-bin/current'), 
                            params={'q1': days_before, 'q2': 0, 'q3': form_type}).text)
    pre = soup.find('pre')
    ls = []
    for line in str(pre).replace('<hr>', '\n').replace('<hr/>', '\n').split('\n'):
        bs_line = BeautifulSoup(line)
        clean_line = '  '.join(item.strip() for item in bs_line.find_all(text=True))
        split_line = [ x.strip() for x in clean_line.split('  ') if x.strip() ]
        split_line += [ a.get('href') for a in bs_line.find_all('a') ]
        if not all(x is None for x in split_line): ls.append(split_line)
    colnames = ls[0] + [ 'link_{}'.format(i) for i in range(max(len(l) for l in ls) - len(ls[0])) ]
    return pd.DataFrame(ls[1:], columns=colnames)

# %%
get_current_events(form_type='8-K').head()
# Out:
#    Date Filed   Form CIK Code                       Company Name  \
# 0  01-08-2021  8-K/A  1599407                  1847 Holdings LLC
# 1  01-08-2021    8-K  1634452   AB Private Credit Investors Corp
# 2  01-08-2021    8-K  1300938                  ABCO Energy, Inc.
# 3  01-08-2021  8-K/A  1813658  ACE Convergence Acquisition Corp.
# 4  01-08-2021    8-K  1004434    AFFILIATED MANAGERS GROUP, INC.
#
#                                               link_0  \
# 0  /Archives/edgar/data/1599407/0001213900-21-001...
# 1  /Archives/edgar/data/1634452/0001193125-21-005...
# 2  /Archives/edgar/data/1300938/0001185185-21-000...
# 3  /Archives/edgar/data/1813658/0001104659-21-002...
# 4  /Archives/edgar/data/1004434/0001193125-21-005...
#
#                                        link_1
# 0  browse-edgar?action=getcompany&CIK=1599407
# 1  browse-edgar?action=getcompany&CIK=1634452
# 2  browse-edgar?action=getcompany&CIK=1300938
# 3  browse-edgar?action=getcompany&CIK=1813658
# 4  browse-edgar?action=getcompany&CIK=1004434

# %% [markdown]
# ## Downloading SEC documents

# %% [markdown]
# Questions:
# * What is the purpose of defining a directory? It does not seem to work when I use it as a parameter for download_sec_documents
#
# * What does the error "index 0 is out of bounds for axis 0 with size 0" mean? I still manage to download the files.

# %%
def download_sec_documents(doc_link):
    contents = clean_sec_content(cach.get(base_url.format(doc_link)).content)
    name = slugify(doc_link)
    with open(name, 'w') as f: f.write(contents)

# %% [markdown]
# #### Downloading 424B5s

# %%
forms = get_current_events(0, '424B5')
for link in forms['link_0']:
    docs = get_filing_documents(base_url.format(link))
    doc_link = docs.loc[docs.Type == '424B5', 'Document'].values[0]
    download_sec_documents(doc_link)

# %% [markdown]
# #### Downloading 8-Ks

# %%
num_days = 2

for p in range(0, num_days):
    print('Scraping day-page:', p)
    forms = get_current_events(p, '8-K')
    for link in forms['link_0']:
        docs = get_filing_documents(base_url.format(link))
        doc_link = docs.loc[docs.Type == '8-K', 'Document'].values[0]
        download_sec_documents(doc_link)
# Out:
# Scraping day-page: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-b32128899b65> in <module>
#       6     for link in forms['link_0']:
#       7         docs = get_filing_documents(base_url.format(link))
# ----> 8         doc_link = docs.loc[docs.Type == '8-K', 'Document'].values[0]
#       9         download_sec_documents(doc_link)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# To download the 8-K I always get the index error above, however when I try to download 424B5 filings this is not a issue. This happens in the filing details page:
#
# 8-K example: https://www.sec.gov/Archives/edgar/data/926660/0001193125-20-298746-index.html
#
# 424B5 example: https://www.sec.gov/Archives/edgar/data/1035443/0001047469-19-001263-index.html

# %% [markdown]
# ## Extracting risk factors

# %% [markdown]
# There is a difference between 424B5 and 8-K forms. The 424B5 forms have summary tables, but we are interested in extracting the text from both forms, not necessarily the tables.
#
# File that I am going to be working with: https://www.sec.gov/Archives/edgar/data/1174940/000149315220022121/form424b5.htm

# %% [markdown]
# ### Parsing 424B5 filings

# %%
content1 = read_html('-archives-edgar-data-1174940-000149315220022121-form424b5.htm')
cleaned_content1 = clean_html(content1)

# %% [markdown]
# First we need to get the headers that delimit the section that includes the description of the risk factors. Once we have the headers, we start looping through every "p" tag that is in between the two headers.
#
# We have to generalize how we find the delimiting headers and insert them inside the function get_risk_info to stop parsing the text on other sections.

# %%
def get_header(soup):
    for header in soup.find_all():
        match = re.match(r'RISK\s*FACTORS\s*', header.text.upper(), re.M) 
        if match:
            if header.name == 'p':
                parent = header.parent
                if parent.name == 'body': ## this is to make it easier to get the delimiting header, since it must be a sibling of header
                    return header

# %%
def get_delimiter_header(content):
    soup = BeautifulSoup(content, 'html.parser') #we use the html parser to list the headers with the sourceline
    positions = []
    for tag in soup.find_all('a'):
        positions.append(tag.string)
    limit = len(positions)
    listing = []
    for i in range(0, limit-1):
        if positions[i] is not None:
            match = re.match(r'RISK\s*FACTORS\s*', str(positions[i]).upper(), re.M) #we spot the target header and select the header that follows it
            if match:
                if positions[i+1] is not None:
                    listing.append(positions[i+1].upper())
                if positions[i+2] is not None:
                    listing.append(positions[i+2].upper())
    return listing

# %%
def get_risk_info(header, content):
    paragraphs = ''
    brother = header.next_sibling
    limit = False
    delimiters = get_delimiter_header(content)
    while brother and limit == False:
        if brother.name == 'p' or brother.name == 'a': # we have to select the tag to use the .get_text attr
            if str(brother.get_text(strip = True)).replace('\n', ' ') in delimiters:
                limit = True
        paragraphs += str(brother)
        brother = brother.next_sibling
    return paragraphs

# %%
def extract_paragraphs(soup, content): 
    header = get_header(soup)
    content_s = get_risk_info(header, content)
    return content_s

# %% [markdown]
# Find out a way to extract the content through extract_paragraphs.
#
# Now I am going to try to parse all the downloaded documents.

# %%
filings_424b5 = []

for html_file in glob('*424b5*.htm'):
    print(html_file)
    content = read_html(html_file)
    cleaned_content = clean_html(content)
    paragraphs = get_risk_info(get_header(cleaned_content),content)
    if paragraphs:
        filings_424b5 += str(paragraphs)
        f = open("4245B5","a")
        f.write(str(paragraphs))
        f.close()
        print('Great success')
# Out:
# -archives-edgar-data-1674930-000156459020054810-flgt-424b5.htm
# Great success
# -archives-edgar-data-1558583-000121390020038382-ea130283-424b5_arcimoto.htm
# Great success
# -archives-edgar-data-864270-000119312520298619-d97515d424b5.htm
# Great success
# -archives-edgar-data-1692412-000119312520298480-d83042d424b5.htm
# Great success
# -archives-edgar-data-1410098-000121390020039655-ea130437-424b5_cormedix.htm
# Great success
# -archives-edgar-data-310764-000119312520299402-d30647d424b5.htm
# Great success
# -archives-edgar-data-1636651-000119312520299425-d947308d424b5.htm
# Great success
# -archives-edgar-data-1623526-000119312520299388-d42479d424b5.htm
# Great success
# -archives-edgar-data-1696396-000119312520299465-d93087d424b5.htm
# Great success
# -archives-edgar-data-1174940-000149315220022121-form424b5.htm
# Great success
# -archives-edgar-data-1316517-000121390020038504-ea130316-424b5_kanditechno.htm
# Great success
# -archives-edgar-data-1182534-000119312520304490-d63319d424b5.htm
# Great success
# -archives-edgar-data-1681087-000119312520299380-d67110d424b5.htm
# Great success
# -archives-edgar-data-1398805-000168316820004102-beam_424b5.htm
# Great success
# -archives-edgar-data-25743-000119312520304588-d62704d424b5.htm
# Great success
# -archives-edgar-data-1629210-000156459020054792-pzg-424b5.htm
# Great success

# %%
f = open("4245B5", "r")
test = f.read()

# %% [markdown]
# The code does work, but the text still includes the html tags.

# %%
def cleanhtml(raw_html):
    cleanr = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});|\n')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

# %%
texty = cleanhtml(test)

# %%
window(str(texty))
# Out:
# <script type="text/javascript">var win = window.open("", "", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = 'Investing in our common stock involves risk. Before deciding whether to invest in our common stock, you should consider carefully the risks and uncertainties described below. You should also consider the risks, uncertainties and assumptions discussed under the heading “Risk Factors” included in our most recent annual report on Form 10-K, as revised or supplemented by our most recent quarterly report on Form 10-Q, each of which are on file with the SEC and are incorporated herein by reference, and which may be amended, supplemented or superseded from time to time by other reports we file with the SEC in the future. There may be other unknown or unpredictable economic, business, competitive, regulatory or other factors that could have material adverse effects on our future results. If any of these risks actually occurs, our business, business prospects, financial condition or results of operations could be seriously harmed. This could cause the trading price of our common stock to decline, resulting in a loss of all or part of your investment. Please also read carefully the section below entitled “Special Note Regarding Forward-Looking Statements.” Risks Related to This Offering and Our Common StockWe will have broad discretion in the use of the net proceeds from this offering and may not use them effectively.We currently intend to use the net proceeds of this offering for working capital and general corporate purposes, as further described in the section of this prospectus supplement entitled “Use of Proceeds.” We will have broad discretion in the application of the net proceeds and investors will be relying on the judgment of our management regarding the application of the proceeds of this offering. The failure by our management to apply these funds effectively could harm our business, financial condition and results of operations. Pending their use, we may invest the net proceeds from this offering in interest-bearing instruments. These investments may not yield a favorable return, or any return, to us or our stockholders.You may experience immediate and substantial dilution.The offering price per share in this offering may exceed the net tangible book value per share of our common stock outstanding prior to this offering. Assuming that an aggregate of 4,030,400 shares of our common stock are sold during the term of the Equity Distribution Agreement with the Sales Agents at a price of $43.42 per share, the last reported sale price of our common stock on Nasdaq on November 18, 2020, for aggregate gross proceeds of approximately $175.0 million, after deducting commissions and estimated aggregate offering expenses payable by us, you will experience immediate dilution of $30.38 per share, representing the difference between the assumed offering price and our as adjusted net tangible book value per share as of September 30, 2020 after giving effect to this offering. The exercise of outstanding stock options and vesting of other stock awards may result in further dilution of your investment. See the section entitled “Dilution” appearing elsewhere in this prospectus supplement for a more detailed illustration of the dilution you would incur if you participate in this offering.The actual number of shares we will issue under the Equity Distribution Agreement with the Sales Agents, at any one time or in total, is uncertain.Subject to certain limitations in the Equity Distribution Agreement with the Sales Agents and compliance with applicable law, we have the discretion to deliver placement notices to the Sales Agents at any time throughout the term of the Equity Distribution Agreement. The number of shares that are sold by the Sales Agents after delivering a placement notic ...

# %% [markdown]
# ## Parsing 8-K files

# %% [markdown]
# The 8-K filings have a different structure so we are just going to refine the functions to work with the 8-K filing structure.

# %%
test = read_html("-archives-edgar-data-1577552-000104746921000247-a2242840z424b5.htm")
testc = clean_html(test)

# %%
file2 = read_html("-archives-edgar-data-1641751-000164175120000033-form-8k.htm")
file2c = clean_html(file2)

# %%
def delim_8k(soup):
    delim = []
    for header in soup.find_all():
        match = re.match(r'Exhibit.*', header.text)
        if match:
            delim.append(header.text)
    return delim


def get_8k_info1(soup):
    paragraphs = ''
    delimiters = delim_8k(soup)
    for header in soup.find_all():
        match = re.match(r'Item.*', header.text)
        if match:
            if header.name == 'p':
                brother = header.next_sibling
                stop = False
                while brother and stop == False:
                    if brother.name == 'table':
                        stop = True
                    if str(brother).strip() in delimiters:
                        stop = True
                    paragraphs += str(brother)
                    brother = brother.next_sibling
                return paragraphs



def get_8k_info(soup):
    paragraphs = []
    for header in soup.find_all():
        match = re.match(r'Item.*', header.text)
        if match:
            if header.name == 'p':
                brother = header.next_sibling
                already_seen = False
                while True:
                    if brother is None:
                        break
                    if type(brother) == NavigableString:
                        if already_seen and str(brother).strip() != '': break
                        brother = brother.next_sibling
                        continue
                    if brother.name == 'table': break
                    already_seen = True
                    paragraphs.append(str(brother))
                    brother = brother.next_sibling
                return(str(paragraphs))

# %%
filings_8k = []

for html_file in glob('*8k*.htm'):
    print(html_file)
    content = read_html(html_file)
    cleaned_content = clean_html(content)
    paragraphs = get_8k_info(cleaned_content)
    if paragraphs:
        filings_8k.append(paragraphs)
        f = open("8ks","a")
        f.write(paragraphs)
        f.close()
        print('Great success')

# %%
f = open("8ks", "r")
test = f.read()

# %% [markdown]
# # Consolidating training data

# %% [markdown]
# Since we will be doing a supervised classification task for the fine-tuning stage of the project, we need to identify each filing with the ticker of the respective company, as well as the prices before and after the publication.
#
# This section is merely to organize the training data in order to see that it is complete, and working.

# %%
# First we are going to get the information about the companies that filed the filings that
# we are going scrape.

num_days = 5
for i in range(0,num_days):
    print('Scraping day-page:', i)
    forms = get_current_events(p, '424B5')

forms.insert(6, 'Text', 'NA')
forms
# Out:
# Scraping day-page: 0
# Scraping day-page: 1
# Scraping day-page: 2
# Scraping day-page: 3
# Scraping day-page: 4
#     Date Filed   Form CIK Code                                Company Name  \
# 0   02-04-2021  424B5  1697862                                   ARGENX SE
# 1   02-04-2021  424B5  1787306               Arcutis Biotherapeutics, Inc.
# 2   02-04-2021  424B5    11544                            BERKLEY W R CORP
# 3   02-04-2021  424B5  1167583              BP CAPITAL MARKETS AMERICA INC
# 4   02-04-2021  424B5   313807                                      BP PLC
# 5   02-04-2021  424B5  1173204                              Cinedigm Corp.
# 6   02-04-2021  424B5   771999               DOCUMENT SECURITY SYSTEMS INC
# 7   02-04-2021  424B5  1082038                                 DURECT CORP
# 8   02-04-2021  424B5  1746466                             Equillium, Inc.
# 9   02-04-2021  424B5  1713832                                HyreCar Inc.
# 10  02-04-2021  424B5   728387                                Isoray, Inc.
# 11  02-04-2021  424B5   821533                                         KfW
# 12  02-04-2021  424B5  1659617                     Moleculin Biotech, Inc.
# 13  02-04-2021  424B5  1642380                               OncoCyte Corp
# 14  02-04-2021  424B5  1474098                     Pebblebrook Hotel Trust
# 15  02-04-2021  424B5  1625101                     Pulse Biosciences, Inc.
# 16  02-04-2021  424B5  1503274                              Quanterix Corp
# 17  02-04-2021  424B5  1697851                         Rekor Systems, Inc.
# 18  02-04-2021  424B5   894158                   Synthetic Biologics, Inc.
# 19  02-04-2021  424B5  1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 20  02-04-2021  424B5  1021162                           TRIUMPH GROUP INC
# 21  02-04-2021  424B5  1838040  Toyota Auto Receivables 2021-A Owner Trust
# 22  02-04-2021  424B5  1163302                    UNITED STATES STEEL CORP
# 23  02-04-2021  424B5  1375205                               UR-ENERGY INC
#
#                                                link_0  \
# 0   /Archives/edgar/data/1697862/0001047469-21-000...
# 1   /Archives/edgar/data/1787306/0001628280-21-001...
# 2   /Archives/edgar/data/11544/0001193125-21-02858...
# 3   /Archives/edgar/data/1167583/0001193125-21-028...
# 4   /Archives/edgar/data/313807/0001193125-21-0285...
# 5   /Archives/edgar/data/1173204/0001104659-21-012...
# 6   /Archives/edgar/data/771999/0001493152-21-0026...
# 7   /Archives/edgar/data/1082038/0001193125-21-027...
# 8   /Archives/edgar/data/1746466/0001193125-21-028...
# 9   /Archives/edgar/data/1713832/0001213900-21-006...
# 10  /Archives/edgar/data/728387/0001437749-21-0020...
# 11  /Archives/edgar/data/821533/0001193125-21-0282...
# 12  /Archives/edgar/data/1659617/0001437749-21-002...
# 13  /Archives/edgar/data/1642380/0001493152-21-002...
# 14  /Archives/edgar/data/1474098/0001104659-21-011...
# 15  /Archives/edgar/data/1625101/0001193125-21-028...
# 16  /Archives/edgar/data/1503274/0001104659-21-012...
# 17  /Archives/edgar/data/1697851/0001193125-21-028...
# 18  /Archives/edgar/data/894158/0001104659-21-0118...
# 19  /Archives/edgar/data/1131131/0000929638-21-000...
# 20  /Archives/edgar/data/1021162/0001193125-21-028...
# 21  /Archives/edgar/data/1838040/0000929638-21-000...
# 22  /Archives/edgar/data/1163302/0001104659-21-012...
# 23  /Archives/edgar/data/1375205/0001104659-21-011...
#
#                                         link_1 Text
# 0   browse-edgar?action=getcompany&CIK=1697862   NA
# 1   browse-edgar?action=getcompany&CIK=1787306   NA
# 2     browse-edgar?action=getcompany&CIK=11544   NA
# 3   browse-edgar?action=getcompany&CIK=1167583   NA
# 4    browse-edgar?action=getcompany&CIK=313807   NA
# 5   browse-edgar?action=getcompany&CIK=1173204   NA
# 6    browse-edgar?action=getcompany&CIK=771999   NA
# 7   browse-edgar?action=getcompany&CIK=1082038   NA
# 8   browse-edgar?action=getcompany&CIK=1746466   NA
# 9   browse-edgar?action=getcompany&CIK=1713832   NA
# 10   browse-edgar?action=getcompany&CIK=728387   NA
# 11   browse-edgar?action=getcompany&CIK=821533   NA
# 12  browse-edgar?action=getcompany&CIK=1659617   NA
# 13  browse-edgar?action=getcompany&CIK=1642380   NA
# 14  browse-edgar?action=getcompany&CIK=1474098   NA
# 15  browse-edgar?action=getcompany&CIK=1625101   NA
# 16  browse-edgar?action=getcompany&CIK=1503274   NA
# 17  browse-edgar?action=getcompany&CIK=1697851   NA
# 18   browse-edgar?action=getcompany&CIK=894158   NA
# 19  browse-edgar?action=getcompany&CIK=1131131   NA
# 20  browse-edgar?action=getcompany&CIK=1021162   NA
# 21  browse-edgar?action=getcompany&CIK=1838040   NA
# 22  browse-edgar?action=getcompany&CIK=1163302   NA
# 23  browse-edgar?action=getcompany&CIK=1375205   NA

# %% [markdown]
# Now we are going to download the filings in the urls extracted, get the risk factors section and add it to the dataframe. The functions to extract the risk factors work for about 75% of the filings, I am having some issues with files that have odd formatting.

# %%
for link in forms['link_0']:
    docs = get_filing_documents(base_url.format(link))
    doc_link = docs.loc[docs.Type == '424B5', 'Document'].values[0]
    download_sec_documents(doc_link)

# %%
files = []

for html_file in glob('*424b5*.htm'):
    files.append(html_file)
    
for i in range(0, len(forms)):
    CIK = forms['CIK Code'][i]
    for file in files:
        match = re.search(CIK, file)
        if match:
            content = read_html(file)
            cleaned_content = clean_html(content)
            paragraphs = get_risk_info1(get_header(cleaned_content), content)
            if paragraphs:
                forms['Text'][i]= cleanhtml(paragraphs)

# %%
forms
# Out:
#     Date Filed   Form CIK Code                                Company Name  \
# 0   02-04-2021  424B5  1697862                                   ARGENX SE
# 1   02-04-2021  424B5  1787306               Arcutis Biotherapeutics, Inc.
# 2   02-04-2021  424B5    11544                            BERKLEY W R CORP
# 3   02-04-2021  424B5  1167583              BP CAPITAL MARKETS AMERICA INC
# 4   02-04-2021  424B5   313807                                      BP PLC
# 5   02-04-2021  424B5  1173204                              Cinedigm Corp.
# 6   02-04-2021  424B5   771999               DOCUMENT SECURITY SYSTEMS INC
# 7   02-04-2021  424B5  1082038                                 DURECT CORP
# 8   02-04-2021  424B5  1746466                             Equillium, Inc.
# 9   02-04-2021  424B5  1713832                                HyreCar Inc.
# 10  02-04-2021  424B5   728387                                Isoray, Inc.
# 11  02-04-2021  424B5   821533                                         KfW
# 12  02-04-2021  424B5  1659617                     Moleculin Biotech, Inc.
# 13  02-04-2021  424B5  1642380                               OncoCyte Corp
# 14  02-04-2021  424B5  1474098                     Pebblebrook Hotel Trust
# 15  02-04-2021  424B5  1625101                     Pulse Biosciences, Inc.
# 16  02-04-2021  424B5  1503274                              Quanterix Corp
# 17  02-04-2021  424B5  1697851                         Rekor Systems, Inc.
# 18  02-04-2021  424B5   894158                   Synthetic Biologics, Inc.
# 19  02-04-2021  424B5  1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 20  02-04-2021  424B5  1021162                           TRIUMPH GROUP INC
# 21  02-04-2021  424B5  1838040  Toyota Auto Receivables 2021-A Owner Trust
# 22  02-04-2021  424B5  1163302                    UNITED STATES STEEL CORP
# 23  02-04-2021  424B5  1375205                               UR-ENERGY INC
#
#                                                link_0  \
# 0   /Archives/edgar/data/1697862/0001047469-21-000...
# 1   /Archives/edgar/data/1787306/0001628280-21-001...
# 2   /Archives/edgar/data/11544/0001193125-21-02858...
# 3   /Archives/edgar/data/1167583/0001193125-21-028...
# 4   /Archives/edgar/data/313807/0001193125-21-0285...
# 5   /Archives/edgar/data/1173204/0001104659-21-012...
# 6   /Archives/edgar/data/771999/0001493152-21-0026...
# 7   /Archives/edgar/data/1082038/0001193125-21-027...
# 8   /Archives/edgar/data/1746466/0001193125-21-028...
# 9   /Archives/edgar/data/1713832/0001213900-21-006...
# 10  /Archives/edgar/data/728387/0001437749-21-0020...
# 11  /Archives/edgar/data/821533/0001193125-21-0282...
# 12  /Archives/edgar/data/1659617/0001437749-21-002...
# 13  /Archives/edgar/data/1642380/0001493152-21-002...
# 14  /Archives/edgar/data/1474098/0001104659-21-011...
# 15  /Archives/edgar/data/1625101/0001193125-21-028...
# 16  /Archives/edgar/data/1503274/0001104659-21-012...
# 17  /Archives/edgar/data/1697851/0001193125-21-028...
# 18  /Archives/edgar/data/894158/0001104659-21-0118...
# 19  /Archives/edgar/data/1131131/0000929638-21-000...
# 20  /Archives/edgar/data/1021162/0001193125-21-028...
# 21  /Archives/edgar/data/1838040/0000929638-21-000...
# 22  /Archives/edgar/data/1163302/0001104659-21-012...
# 23  /Archives/edgar/data/1375205/0001104659-21-011...
#
#                                         link_1  \
# 0   browse-edgar?action=getcompany&CIK=1697862
# 1   browse-edgar?action=getcompany&CIK=1787306
# 2     browse-edgar?action=getcompany&CIK=11544
# 3   browse-edgar?action=getcompany&CIK=1167583
# 4    browse-edgar?action=getcompany&CIK=313807
# 5   browse-edgar?action=getcompany&CIK=1173204
# 6    browse-edgar?action=getcompany&CIK=771999
# 7   browse-edgar?action=getcompany&CIK=1082038
# 8   browse-edgar?action=getcompany&CIK=1746466
# 9   browse-edgar?action=getcompany&CIK=1713832
# 10   browse-edgar?action=getcompany&CIK=728387
# 11   browse-edgar?action=getcompany&CIK=821533
# 12  browse-edgar?action=getcompany&CIK=1659617
# 13  browse-edgar?action=getcompany&CIK=1642380
# 14  browse-edgar?action=getcompany&CIK=1474098
# 15  browse-edgar?action=getcompany&CIK=1625101
# 16  browse-edgar?action=getcompany&CIK=1503274
# 17  browse-edgar?action=getcompany&CIK=1697851
# 18   browse-edgar?action=getcompany&CIK=894158
# 19  browse-edgar?action=getcompany&CIK=1131131
# 20  browse-edgar?action=getcompany&CIK=1021162
# 21  browse-edgar?action=getcompany&CIK=1838040
# 22  browse-edgar?action=getcompany&CIK=1163302
# 23  browse-edgar?action=getcompany&CIK=1375205
#
#                                                  Text
# 0                                                  NA
# 1   You should consider carefully the risks descri...
# 2   Before you invest in the debentures, you shoul...
# 3                                                  NA
# 4   Investing in the securities offered using this...
# 5   Before you invest in shares of our ClassA comm...
# 6   Ourbusiness is influenced by many factors that...
# 7   Before you invest in our common stock, in addi...
# 8   Investing in our securities involves a high de...
# 9   Investing in ourcommon stock involves a high d...
# 10  Investinginoursecuritiesinvolvesahighdegreeofr...
# 11                                                 NA
# 12  An investment in our common stock involves ris...
# 13  Investingin our securities involves a high deg...
# 14                                                 NA
# 15  Investing in our common stock involves a high ...
# 16                                                 NA
# 17  Investing in our common stock involves a high ...
# 18  Investing in our common stock involvesa high d...
# 19  You should consider the following risk factors...
# 20  Investing in our common stock involves a high ...
# 21                                                 NA
# 22                                                 NA
# 23  An investment inour securities involves a high...

# %% [markdown]
# Now I am going to get the tickers of these companies based on their CIK Code, which was what we got from the SEC.

# %%
tickers = cach.get(base_url.format('/files/company_tickers.json')).json()
tickers = pd.DataFrame(tickers)
tickers
# Out:
#                   0               1               2              3  \
# cik_str      320193          789019         1018724        1652044
# ticker         AAPL            MSFT            AMZN           GOOG
# title    Apple Inc.  MICROSOFT CORP  AMAZON COM INC  Alphabet Inc.
#
#                             4            5             6  \
# cik_str               1293451      1318605       1326801
# ticker                  TCEHY         TSLA            FB
# title    Tencent Holdings Ltd  Tesla, Inc.  Facebook Inc
#
#                                  7                                          8  \
# cik_str                    1577552                                    1046179
# ticker                        BABA                                        TSM
# title    Alibaba Group Holding Ltd  TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD
#
#                               9  ...                  10896  \
# cik_str                 1067983  ...                1819794
# ticker                    BRK-A  ...                  HTOOW
# title    BERKSHIRE HATHAWAY INC  ...  Fusion Fuel Green PLC
#
#                                10897                     10898  \
# cik_str                      1819615                   1819608
# ticker                         CLVRW                   AVAN-UN
# title    Clever Leaves Holdings Inc.  Avanti Acquisition Corp.
#
#                             10899                                  10900  \
# cik_str                   1819608                                1819516
# ticker                    AVAN-WT                                ASPL-UN
# title    Avanti Acquisition Corp.  Aspirational Consumer Lifestyle Corp.
#
#                                          10901  \
# cik_str                                1819516
# ticker                                 ASPL-WT
# title    Aspirational Consumer Lifestyle Corp.
#
#                                    10902                            10903  \
# cik_str                          1819574                          1819574
# ticker                           STIC-UN                          STIC-WT
# title    Northern Star Acquisition Corp.  Northern Star Acquisition Corp.
#
#                                  10904                          10905
# cik_str                        1819584                        1819584
# ticker                         SNPR-UN                        SNPR-WT
# title    Tortoise Acquisition Corp. II  Tortoise Acquisition Corp. II
#
# [3 rows x 10906 columns]

# %%
tickers_t = tickers.transpose()
tickers_t.head()
# Out:
#    cik_str ticker                 title
# 0   320193   AAPL            Apple Inc.
# 1   789019   MSFT        MICROSOFT CORP
# 2  1018724   AMZN        AMAZON COM INC
# 3  1652044   GOOG         Alphabet Inc.
# 4  1293451  TCEHY  Tencent Holdings Ltd

# %%
tickers_t = tickers_t.drop(['title'], axis = 1)
tickers_t.columns = ['CIK Code', 'Ticker']
tickers_t.head()
# Out:
#   CIK Code Ticker
# 0   320193   AAPL
# 1   789019   MSFT
# 2  1018724   AMZN
# 3  1652044   GOOG
# 4  1293451  TCEHY

# %%
forms['CIK Code'] = forms['CIK Code'].astype(int)
tickers_t['CIK Code'] = tickers_t['CIK Code'].astype(int)

# %%
exp = forms.merge(tickers_t, on = 'CIK Code', how = 'left')
exp
# Out:
#     Date Filed   Form  CIK Code                                Company Name  \
# 0   02-04-2021  424B5   1697862                                   ARGENX SE
# 1   02-04-2021  424B5   1787306               Arcutis Biotherapeutics, Inc.
# 2   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 3   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 4   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 5   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 6   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 7   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 8   02-04-2021  424B5   1167583              BP CAPITAL MARKETS AMERICA INC
# 9   02-04-2021  424B5    313807                                      BP PLC
# 10  02-04-2021  424B5   1173204                              Cinedigm Corp.
# 11  02-04-2021  424B5    771999               DOCUMENT SECURITY SYSTEMS INC
# 12  02-04-2021  424B5   1082038                                 DURECT CORP
# 13  02-04-2021  424B5   1746466                             Equillium, Inc.
# 14  02-04-2021  424B5   1713832                                HyreCar Inc.
# 15  02-04-2021  424B5    728387                                Isoray, Inc.
# 16  02-04-2021  424B5    821533                                         KfW
# 17  02-04-2021  424B5   1659617                     Moleculin Biotech, Inc.
# 18  02-04-2021  424B5   1642380                               OncoCyte Corp
# 19  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 20  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 21  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 22  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 23  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 24  02-04-2021  424B5   1625101                     Pulse Biosciences, Inc.
# 25  02-04-2021  424B5   1503274                              Quanterix Corp
# 26  02-04-2021  424B5   1697851                         Rekor Systems, Inc.
# 27  02-04-2021  424B5    894158                   Synthetic Biologics, Inc.
# 28  02-04-2021  424B5   1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 29  02-04-2021  424B5   1021162                           TRIUMPH GROUP INC
# 30  02-04-2021  424B5   1838040  Toyota Auto Receivables 2021-A Owner Trust
# 31  02-04-2021  424B5   1163302                    UNITED STATES STEEL CORP
# 32  02-04-2021  424B5   1375205                               UR-ENERGY INC
#
#                                                link_0  \
# 0   /Archives/edgar/data/1697862/0001047469-21-000...
# 1   /Archives/edgar/data/1787306/0001628280-21-001...
# 2   /Archives/edgar/data/11544/0001193125-21-02858...
# 3   /Archives/edgar/data/11544/0001193125-21-02858...
# 4   /Archives/edgar/data/11544/0001193125-21-02858...
# 5   /Archives/edgar/data/11544/0001193125-21-02858...
# 6   /Archives/edgar/data/11544/0001193125-21-02858...
# 7   /Archives/edgar/data/11544/0001193125-21-02858...
# 8   /Archives/edgar/data/1167583/0001193125-21-028...
# 9   /Archives/edgar/data/313807/0001193125-21-0285...
# 10  /Archives/edgar/data/1173204/0001104659-21-012...
# 11  /Archives/edgar/data/771999/0001493152-21-0026...
# 12  /Archives/edgar/data/1082038/0001193125-21-027...
# 13  /Archives/edgar/data/1746466/0001193125-21-028...
# 14  /Archives/edgar/data/1713832/0001213900-21-006...
# 15  /Archives/edgar/data/728387/0001437749-21-0020...
# 16  /Archives/edgar/data/821533/0001193125-21-0282...
# 17  /Archives/edgar/data/1659617/0001437749-21-002...
# 18  /Archives/edgar/data/1642380/0001493152-21-002...
# 19  /Archives/edgar/data/1474098/0001104659-21-011...
# 20  /Archives/edgar/data/1474098/0001104659-21-011...
# 21  /Archives/edgar/data/1474098/0001104659-21-011...
# 22  /Archives/edgar/data/1474098/0001104659-21-011...
# 23  /Archives/edgar/data/1474098/0001104659-21-011...
# 24  /Archives/edgar/data/1625101/0001193125-21-028...
# 25  /Archives/edgar/data/1503274/0001104659-21-012...
# 26  /Archives/edgar/data/1697851/0001193125-21-028...
# 27  /Archives/edgar/data/894158/0001104659-21-0118...
# 28  /Archives/edgar/data/1131131/0000929638-21-000...
# 29  /Archives/edgar/data/1021162/0001193125-21-028...
# 30  /Archives/edgar/data/1838040/0000929638-21-000...
# 31  /Archives/edgar/data/1163302/0001104659-21-012...
# 32  /Archives/edgar/data/1375205/0001104659-21-011...
#
#                                         link_1  \
# 0   browse-edgar?action=getcompany&CIK=1697862
# 1   browse-edgar?action=getcompany&CIK=1787306
# 2     browse-edgar?action=getcompany&CIK=11544
# 3     browse-edgar?action=getcompany&CIK=11544
# 4     browse-edgar?action=getcompany&CIK=11544
# 5     browse-edgar?action=getcompany&CIK=11544
# 6     browse-edgar?action=getcompany&CIK=11544
# 7     browse-edgar?action=getcompany&CIK=11544
# 8   browse-edgar?action=getcompany&CIK=1167583
# 9    browse-edgar?action=getcompany&CIK=313807
# 10  browse-edgar?action=getcompany&CIK=1173204
# 11   browse-edgar?action=getcompany&CIK=771999
# 12  browse-edgar?action=getcompany&CIK=1082038
# 13  browse-edgar?action=getcompany&CIK=1746466
# 14  browse-edgar?action=getcompany&CIK=1713832
# 15   browse-edgar?action=getcompany&CIK=728387
# 16   browse-edgar?action=getcompany&CIK=821533
# 17  browse-edgar?action=getcompany&CIK=1659617
# 18  browse-edgar?action=getcompany&CIK=1642380
# 19  browse-edgar?action=getcompany&CIK=1474098
# 20  browse-edgar?action=getcompany&CIK=1474098
# 21  browse-edgar?action=getcompany&CIK=1474098
# 22  browse-edgar?action=getcompany&CIK=1474098
# 23  browse-edgar?action=getcompany&CIK=1474098
# 24  browse-edgar?action=getcompany&CIK=1625101
# 25  browse-edgar?action=getcompany&CIK=1503274
# 26  browse-edgar?action=getcompany&CIK=1697851
# 27   browse-edgar?action=getcompany&CIK=894158
# 28  browse-edgar?action=getcompany&CIK=1131131
# 29  browse-edgar?action=getcompany&CIK=1021162
# 30  browse-edgar?action=getcompany&CIK=1838040
# 31  browse-edgar?action=getcompany&CIK=1163302
# 32  browse-edgar?action=getcompany&CIK=1375205
#
#                                                  Text  Ticker
# 0                                                  NA    ARGX
# 1   You should consider carefully the risks descri...    ARQT
# 2   Before you invest in the debentures, you shoul...     WRB
# 3   Before you invest in the debentures, you shoul...  WRB-PC
# 4   Before you invest in the debentures, you shoul...  WRB-PE
# 5   Before you invest in the debentures, you shoul...  WRB-PD
# 6   Before you invest in the debentures, you shoul...  WRB-PF
# 7   Before you invest in the debentures, you shoul...  WRB-PG
# 8                                                  NA     NaN
# 9   Investing in the securities offered using this...      BP
# 10  Before you invest in shares of our ClassA comm...    CIDM
# 11  Ourbusiness is influenced by many factors that...     DSS
# 12  Before you invest in our common stock, in addi...    DRRX
# 13  Investing in our securities involves a high de...      EQ
# 14  Investing in ourcommon stock involves a high d...    HYRE
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...     ISR
# 16                                                 NA     NaN
# 17  An investment in our common stock involves ris...    MBRX
# 18  Investingin our securities involves a high deg...     OCX
# 19                                                 NA     PEB
# 20                                                 NA  PEB-PE
# 21                                                 NA  PEB-PC
# 22                                                 NA  PEB-PF
# 23                                                 NA  PEB-PD
# 24  Investing in our common stock involves a high ...    PLSE
# 25                                                 NA    QTRX
# 26  Investing in our common stock involves a high ...    REKR
# 27  Investing in our common stock involvesa high d...     SYN
# 28  You should consider the following risk factors...     NaN
# 29  Investing in our common stock involves a high ...     TGI
# 30                                                 NA     NaN
# 31                                                 NA       X
# 32  An investment inour securities involves a high...     URG

# %%
exp = exp.drop(['link_0', 'link_1'], axis = 1)
exp
# Out:
#     Date Filed   Form  CIK Code                                Company Name  \
# 0   02-04-2021  424B5   1697862                                   ARGENX SE
# 1   02-04-2021  424B5   1787306               Arcutis Biotherapeutics, Inc.
# 2   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 3   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 4   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 5   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 6   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 7   02-04-2021  424B5     11544                            BERKLEY W R CORP
# 8   02-04-2021  424B5   1167583              BP CAPITAL MARKETS AMERICA INC
# 9   02-04-2021  424B5    313807                                      BP PLC
# 10  02-04-2021  424B5   1173204                              Cinedigm Corp.
# 11  02-04-2021  424B5    771999               DOCUMENT SECURITY SYSTEMS INC
# 12  02-04-2021  424B5   1082038                                 DURECT CORP
# 13  02-04-2021  424B5   1746466                             Equillium, Inc.
# 14  02-04-2021  424B5   1713832                                HyreCar Inc.
# 15  02-04-2021  424B5    728387                                Isoray, Inc.
# 16  02-04-2021  424B5    821533                                         KfW
# 17  02-04-2021  424B5   1659617                     Moleculin Biotech, Inc.
# 18  02-04-2021  424B5   1642380                               OncoCyte Corp
# 19  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 20  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 21  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 22  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 23  02-04-2021  424B5   1474098                     Pebblebrook Hotel Trust
# 24  02-04-2021  424B5   1625101                     Pulse Biosciences, Inc.
# 25  02-04-2021  424B5   1503274                              Quanterix Corp
# 26  02-04-2021  424B5   1697851                         Rekor Systems, Inc.
# 27  02-04-2021  424B5    894158                   Synthetic Biologics, Inc.
# 28  02-04-2021  424B5   1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 29  02-04-2021  424B5   1021162                           TRIUMPH GROUP INC
# 30  02-04-2021  424B5   1838040  Toyota Auto Receivables 2021-A Owner Trust
# 31  02-04-2021  424B5   1163302                    UNITED STATES STEEL CORP
# 32  02-04-2021  424B5   1375205                               UR-ENERGY INC
#
#                                                  Text  Ticker
# 0                                                  NA    ARGX
# 1   You should consider carefully the risks descri...    ARQT
# 2   Before you invest in the debentures, you shoul...     WRB
# 3   Before you invest in the debentures, you shoul...  WRB-PC
# 4   Before you invest in the debentures, you shoul...  WRB-PE
# 5   Before you invest in the debentures, you shoul...  WRB-PD
# 6   Before you invest in the debentures, you shoul...  WRB-PF
# 7   Before you invest in the debentures, you shoul...  WRB-PG
# 8                                                  NA     NaN
# 9   Investing in the securities offered using this...      BP
# 10  Before you invest in shares of our ClassA comm...    CIDM
# 11  Ourbusiness is influenced by many factors that...     DSS
# 12  Before you invest in our common stock, in addi...    DRRX
# 13  Investing in our securities involves a high de...      EQ
# 14  Investing in ourcommon stock involves a high d...    HYRE
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...     ISR
# 16                                                 NA     NaN
# 17  An investment in our common stock involves ris...    MBRX
# 18  Investingin our securities involves a high deg...     OCX
# 19                                                 NA     PEB
# 20                                                 NA  PEB-PE
# 21                                                 NA  PEB-PC
# 22                                                 NA  PEB-PF
# 23                                                 NA  PEB-PD
# 24  Investing in our common stock involves a high ...    PLSE
# 25                                                 NA    QTRX
# 26  Investing in our common stock involves a high ...    REKR
# 27  Investing in our common stock involvesa high d...     SYN
# 28  You should consider the following risk factors...     NaN
# 29  Investing in our common stock involves a high ...     TGI
# 30                                                 NA     NaN
# 31                                                 NA       X
# 32  An investment inour securities involves a high...     URG

# %% [markdown]
# ## Merging with financial data
# <br> </br>
#
# So now the dataframe with the textual data is complete. Now we are going to use the tickers and the date of the publication to get the stock prices we are interested in.

# %%
import yfinance as yf
from datetime import datetime, timedelta

# %%
def previous_close_and_next_open(tickers, dates):
    """This function obtains, for each pair of ticker and date, the closing price of the ticker during the 
    day before the given date and the opening price of the ticker for the day next to the reference date.
    
    For the inputs:
    tickers: List of tickers, each represented by a string
    dates: List of dates, each represented in the format %Y-%m-%d (2010-01-24)
    
    The output is a pandas dataframe, with as many rows as specified tickers, and columns Reference Date, Previous Close,
    and Next Open."""
    
    results = pd.DataFrame(columns=['Ticker', "Reference Date", "Previous Close", "Next Open"]).set_index('Ticker')
    for i, t in enumerate(tickers):
        #If date falls in weekends, take Friday and Monday
        extra_add = extra_sub = 0
        if datetime.strptime(dates[i], '%Y-%m-%d').isoweekday() == 6:
            extra_add = 1
        elif datetime.strptime(dates[i], '%Y-%m-%d').isoweekday() == 7:
            extra_sub = 1
                
        yesterday = datetime.strptime(dates[i], '%Y-%m-%d') - timedelta(days=1+ extra_sub)
        tomorrow = datetime.strptime(dates[i], '%Y-%m-%d') + timedelta(days=1 + extra_add)
        
        data = yf.download(t, start=yesterday + timedelta(days=1), end=tomorrow + timedelta(days=1))
        
        previous_close = data.iloc[0]['Close']
        next_open = data.iloc[-1]['Open']

        single = pd.DataFrame({"Reference Date":dates[i], "Previous Close":previous_close, "Next Open":next_open}, index=[t])
        results = results.append(single)
    return results

# %%
exp['Date Filed'] = pd.to_datetime(exp['Date Filed'], format = '%m-%d-%Y')
exp
# Out:
#    Date Filed   Form  CIK Code                                Company Name  \
# 0  2021-02-04  424B5   1697862                                   ARGENX SE
# 1  2021-02-04  424B5   1787306               Arcutis Biotherapeutics, Inc.
# 2  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 3  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 4  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 5  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 6  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 7  2021-02-04  424B5     11544                            BERKLEY W R CORP
# 8  2021-02-04  424B5   1167583              BP CAPITAL MARKETS AMERICA INC
# 9  2021-02-04  424B5    313807                                      BP PLC
# 10 2021-02-04  424B5   1173204                              Cinedigm Corp.
# 11 2021-02-04  424B5    771999               DOCUMENT SECURITY SYSTEMS INC
# 12 2021-02-04  424B5   1082038                                 DURECT CORP
# 13 2021-02-04  424B5   1746466                             Equillium, Inc.
# 14 2021-02-04  424B5   1713832                                HyreCar Inc.
# 15 2021-02-04  424B5    728387                                Isoray, Inc.
# 16 2021-02-04  424B5    821533                                         KfW
# 17 2021-02-04  424B5   1659617                     Moleculin Biotech, Inc.
# 18 2021-02-04  424B5   1642380                               OncoCyte Corp
# 19 2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 20 2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 21 2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 22 2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 23 2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 24 2021-02-04  424B5   1625101                     Pulse Biosciences, Inc.
# 25 2021-02-04  424B5   1503274                              Quanterix Corp
# 26 2021-02-04  424B5   1697851                         Rekor Systems, Inc.
# 27 2021-02-04  424B5    894158                   Synthetic Biologics, Inc.
# 28 2021-02-04  424B5   1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 29 2021-02-04  424B5   1021162                           TRIUMPH GROUP INC
# 30 2021-02-04  424B5   1838040  Toyota Auto Receivables 2021-A Owner Trust
# 31 2021-02-04  424B5   1163302                    UNITED STATES STEEL CORP
# 32 2021-02-04  424B5   1375205                               UR-ENERGY INC
#
#                                                  Text  Ticker
# 0                                                  NA    ARGX
# 1   You should consider carefully the risks descri...    ARQT
# 2   Before you invest in the debentures, you shoul...     WRB
# 3   Before you invest in the debentures, you shoul...  WRB-PC
# 4   Before you invest in the debentures, you shoul...  WRB-PE
# 5   Before you invest in the debentures, you shoul...  WRB-PD
# 6   Before you invest in the debentures, you shoul...  WRB-PF
# 7   Before you invest in the debentures, you shoul...  WRB-PG
# 8                                                  NA     NaN
# 9   Investing in the securities offered using this...      BP
# 10  Before you invest in shares of our ClassA comm...    CIDM
# 11  Ourbusiness is influenced by many factors that...     DSS
# 12  Before you invest in our common stock, in addi...    DRRX
# 13  Investing in our securities involves a high de...      EQ
# 14  Investing in ourcommon stock involves a high d...    HYRE
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...     ISR
# 16                                                 NA     NaN
# 17  An investment in our common stock involves ris...    MBRX
# 18  Investingin our securities involves a high deg...     OCX
# 19                                                 NA     PEB
# 20                                                 NA  PEB-PE
# 21                                                 NA  PEB-PC
# 22                                                 NA  PEB-PF
# 23                                                 NA  PEB-PD
# 24  Investing in our common stock involves a high ...    PLSE
# 25                                                 NA    QTRX
# 26  Investing in our common stock involves a high ...    REKR
# 27  Investing in our common stock involvesa high d...     SYN
# 28  You should consider the following risk factors...     NaN
# 29  Investing in our common stock involves a high ...     TGI
# 30                                                 NA     NaN
# 31                                                 NA       X
# 32  An investment inour securities involves a high...     URG

# %%
exp['Date Filed'] = exp['Date Filed'].dt.strftime('%Y-%m-%d')

# %%
exp
# Out:
#     Date Filed   Form  CIK Code                                Company Name  \
# 0   2021-02-04  424B5   1697862                                   ARGENX SE
# 1   2021-02-04  424B5   1787306               Arcutis Biotherapeutics, Inc.
# 2   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 3   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 4   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 5   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 6   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 7   2021-02-04  424B5     11544                            BERKLEY W R CORP
# 8   2021-02-04  424B5   1167583              BP CAPITAL MARKETS AMERICA INC
# 9   2021-02-04  424B5    313807                                      BP PLC
# 10  2021-02-04  424B5   1173204                              Cinedigm Corp.
# 11  2021-02-04  424B5    771999               DOCUMENT SECURITY SYSTEMS INC
# 12  2021-02-04  424B5   1082038                                 DURECT CORP
# 13  2021-02-04  424B5   1746466                             Equillium, Inc.
# 14  2021-02-04  424B5   1713832                                HyreCar Inc.
# 15  2021-02-04  424B5    728387                                Isoray, Inc.
# 16  2021-02-04  424B5    821533                                         KfW
# 17  2021-02-04  424B5   1659617                     Moleculin Biotech, Inc.
# 18  2021-02-04  424B5   1642380                               OncoCyte Corp
# 19  2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 20  2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 21  2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 22  2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 23  2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 24  2021-02-04  424B5   1625101                     Pulse Biosciences, Inc.
# 25  2021-02-04  424B5   1503274                              Quanterix Corp
# 26  2021-02-04  424B5   1697851                         Rekor Systems, Inc.
# 27  2021-02-04  424B5    894158                   Synthetic Biologics, Inc.
# 28  2021-02-04  424B5   1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 29  2021-02-04  424B5   1021162                           TRIUMPH GROUP INC
# 30  2021-02-04  424B5   1838040  Toyota Auto Receivables 2021-A Owner Trust
# 31  2021-02-04  424B5   1163302                    UNITED STATES STEEL CORP
# 32  2021-02-04  424B5   1375205                               UR-ENERGY INC
#
#                                                  Text  Ticker
# 0                                                  NA    ARGX
# 1   You should consider carefully the risks descri...    ARQT
# 2   Before you invest in the debentures, you shoul...     WRB
# 3   Before you invest in the debentures, you shoul...  WRB-PC
# 4   Before you invest in the debentures, you shoul...  WRB-PE
# 5   Before you invest in the debentures, you shoul...  WRB-PD
# 6   Before you invest in the debentures, you shoul...  WRB-PF
# 7   Before you invest in the debentures, you shoul...  WRB-PG
# 8                                                  NA     NaN
# 9   Investing in the securities offered using this...      BP
# 10  Before you invest in shares of our ClassA comm...    CIDM
# 11  Ourbusiness is influenced by many factors that...     DSS
# 12  Before you invest in our common stock, in addi...    DRRX
# 13  Investing in our securities involves a high de...      EQ
# 14  Investing in ourcommon stock involves a high d...    HYRE
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...     ISR
# 16                                                 NA     NaN
# 17  An investment in our common stock involves ris...    MBRX
# 18  Investingin our securities involves a high deg...     OCX
# 19                                                 NA     PEB
# 20                                                 NA  PEB-PE
# 21                                                 NA  PEB-PC
# 22                                                 NA  PEB-PF
# 23                                                 NA  PEB-PD
# 24  Investing in our common stock involves a high ...    PLSE
# 25                                                 NA    QTRX
# 26  Investing in our common stock involves a high ...    REKR
# 27  Investing in our common stock involvesa high d...     SYN
# 28  You should consider the following risk factors...     NaN
# 29  Investing in our common stock involves a high ...     TGI
# 30                                                 NA     NaN
# 31                                                 NA       X
# 32  An investment inour securities involves a high...     URG

# %%
tickers = list(exp['Ticker'])
dates = list(exp['Date Filed'])

# %%
tickers
# Out:
# ['ARGX',
#  'ARQT',
#  'WRB',
#  'WRB-PC',
#  'WRB-PE',
#  'WRB-PD',
#  'WRB-PF',
#  'WRB-PG',
#  nan,
#  'BP',
#  'CIDM',
#  'DSS',
#  'DRRX',
#  'EQ',
#  'HYRE',
#  'ISR',
#  nan,
#  'MBRX',
#  'OCX',
#  'PEB',
#  'PEB-PE',
#  'PEB-PC',
#  'PEB-PF',
#  'PEB-PD',
#  'PLSE',
#  'QTRX',
#  'REKR',
#  'SYN',
#  nan,
#  'TGI',
#  nan,
#  'X',
#  'URG']

# %%
tickers_cleaned = [i for i in tickers if (str(i) != 'nan' and len(str(i))<5)]
dates_cleaned = exp['Date Filed'][:-(len(tickers)-len(tickers_cleaned))]

# %%
len(dates_cleaned)
# Out:
# 20

# %%
df = previous_close_and_next_open(tickers_cleaned, dates_cleaned)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#      Reference Date  Previous Close   Next Open
# ARGX     2021-02-04      362.440002  370.500000
# ARQT     2021-02-04       34.630001   35.500000
# WRB      2021-02-04       63.599998   65.360001
# BP       2021-02-04       21.270000   21.000000
# CIDM     2021-02-04        1.630000    1.940000

# %%
df = df.reset_index()
df.columns = ['Ticker', 'Date Filed', 'Previous Close', 'Next Open']

# %%
df
# Out:
#    Ticker  Date Filed  Previous Close   Next Open
# 0    ARGX  2021-02-04      362.440002  370.500000
# 1    ARQT  2021-02-04       34.630001   35.500000
# 2     WRB  2021-02-04       63.599998   65.360001
# 3      BP  2021-02-04       21.270000   21.000000
# 4    CIDM  2021-02-04        1.630000    1.940000
# 5     DSS  2021-02-04        4.380000    3.020000
# 6    DRRX  2021-02-04        2.870000    2.570000
# 7      EQ  2021-02-04        6.620000    7.880000
# 8    HYRE  2021-02-04       15.620000   14.990000
# 9     ISR  2021-02-04        1.890000    1.600000
# 10   MBRX  2021-02-04        4.680000    4.975000
# 11    OCX  2021-02-04        5.350000    5.630000
# 12    PEB  2021-02-04       19.969999   19.650000
# 13   PLSE  2021-02-04       36.619999   41.139999
# 14   QTRX  2021-02-04       72.459999   79.800003
# 15   REKR  2021-02-04       14.770000   13.400000
# 16    SYN  2021-02-04        0.830000    0.830000
# 17    TGI  2021-02-04       13.430000   14.040000
# 18      X  2021-02-04       16.260000   16.650000
# 19    URG  2021-02-04        0.920000    0.920000

# %%
exp1 = exp.merge(df, on ='Ticker', how = 'left')
exp1
# Out:
#    Date Filed_x   Form  CIK Code                                Company Name  \
# 0    2021-02-04  424B5   1697862                                   ARGENX SE
# 1    2021-02-04  424B5   1787306               Arcutis Biotherapeutics, Inc.
# 2    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 3    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 4    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 5    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 6    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 7    2021-02-04  424B5     11544                            BERKLEY W R CORP
# 8    2021-02-04  424B5   1167583              BP CAPITAL MARKETS AMERICA INC
# 9    2021-02-04  424B5    313807                                      BP PLC
# 10   2021-02-04  424B5   1173204                              Cinedigm Corp.
# 11   2021-02-04  424B5    771999               DOCUMENT SECURITY SYSTEMS INC
# 12   2021-02-04  424B5   1082038                                 DURECT CORP
# 13   2021-02-04  424B5   1746466                             Equillium, Inc.
# 14   2021-02-04  424B5   1713832                                HyreCar Inc.
# 15   2021-02-04  424B5    728387                                Isoray, Inc.
# 16   2021-02-04  424B5    821533                                         KfW
# 17   2021-02-04  424B5   1659617                     Moleculin Biotech, Inc.
# 18   2021-02-04  424B5   1642380                               OncoCyte Corp
# 19   2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 20   2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 21   2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 22   2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 23   2021-02-04  424B5   1474098                     Pebblebrook Hotel Trust
# 24   2021-02-04  424B5   1625101                     Pulse Biosciences, Inc.
# 25   2021-02-04  424B5   1503274                              Quanterix Corp
# 26   2021-02-04  424B5   1697851                         Rekor Systems, Inc.
# 27   2021-02-04  424B5    894158                   Synthetic Biologics, Inc.
# 28   2021-02-04  424B5   1131131         TOYOTA AUTO FINANCE RECEIVABLES LLC
# 29   2021-02-04  424B5   1021162                           TRIUMPH GROUP INC
# 30   2021-02-04  424B5   1838040  Toyota Auto Receivables 2021-A Owner Trust
# 31   2021-02-04  424B5   1163302                    UNITED STATES STEEL CORP
# 32   2021-02-04  424B5   1375205                               UR-ENERGY INC
#
#                                                  Text  Ticker Date Filed_y  \
# 0                                                  NA    ARGX   2021-02-04
# 1   You should consider carefully the risks descri...    ARQT   2021-02-04
# 2   Before you invest in the debentures, you shoul...     WRB   2021-02-04
# 3   Before you invest in the debentures, you shoul...  WRB-PC          NaN
# 4   Before you invest in the debentures, you shoul...  WRB-PE          NaN
# 5   Before you invest in the debentures, you shoul...  WRB-PD          NaN
# 6   Before you invest in the debentures, you shoul...  WRB-PF          NaN
# 7   Before you invest in the debentures, you shoul...  WRB-PG          NaN
# 8                                                  NA     NaN          NaN
# 9   Investing in the securities offered using this...      BP   2021-02-04
# 10  Before you invest in shares of our ClassA comm...    CIDM   2021-02-04
# 11  Ourbusiness is influenced by many factors that...     DSS   2021-02-04
# 12  Before you invest in our common stock, in addi...    DRRX   2021-02-04
# 13  Investing in our securities involves a high de...      EQ   2021-02-04
# 14  Investing in ourcommon stock involves a high d...    HYRE   2021-02-04
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...     ISR   2021-02-04
# 16                                                 NA     NaN          NaN
# 17  An investment in our common stock involves ris...    MBRX   2021-02-04
# 18  Investingin our securities involves a high deg...     OCX   2021-02-04
# 19                                                 NA     PEB   2021-02-04
# 20                                                 NA  PEB-PE          NaN
# 21                                                 NA  PEB-PC          NaN
# 22                                                 NA  PEB-PF          NaN
# 23                                                 NA  PEB-PD          NaN
# 24  Investing in our common stock involves a high ...    PLSE   2021-02-04
# 25                                                 NA    QTRX   2021-02-04
# 26  Investing in our common stock involves a high ...    REKR   2021-02-04
# 27  Investing in our common stock involvesa high d...     SYN   2021-02-04
# 28  You should consider the following risk factors...     NaN          NaN
# 29  Investing in our common stock involves a high ...     TGI   2021-02-04
# 30                                                 NA     NaN          NaN
# 31                                                 NA       X   2021-02-04
# 32  An investment inour securities involves a high...     URG   2021-02-04
#
#     Previous Close   Next Open
# 0       362.440002  370.500000
# 1        34.630001   35.500000
# 2        63.599998   65.360001
# 3              NaN         NaN
# 4              NaN         NaN
# 5              NaN         NaN
# 6              NaN         NaN
# 7              NaN         NaN
# 8              NaN         NaN
# 9        21.270000   21.000000
# 10        1.630000    1.940000
# 11        4.380000    3.020000
# 12        2.870000    2.570000
# 13        6.620000    7.880000
# 14       15.620000   14.990000
# 15        1.890000    1.600000
# 16             NaN         NaN
# 17        4.680000    4.975000
# 18        5.350000    5.630000
# 19       19.969999   19.650000
# 20             NaN         NaN
# 21             NaN         NaN
# 22             NaN         NaN
# 23             NaN         NaN
# 24       36.619999   41.139999
# 25       72.459999   79.800003
# 26       14.770000   13.400000
# 27        0.830000    0.830000
# 28             NaN         NaN
# 29       13.430000   14.040000
# 30             NaN         NaN
# 31       16.260000   16.650000
# 32        0.920000    0.920000

# %%
exp1.dropna(axis = 0, how = 'any', inplace = True)
# Out:
#    Date Filed_x   Form  CIK Code                   Company Name  \
# 0    2021-02-04  424B5   1697862                      ARGENX SE
# 1    2021-02-04  424B5   1787306  Arcutis Biotherapeutics, Inc.
# 2    2021-02-04  424B5     11544               BERKLEY W R CORP
# 9    2021-02-04  424B5    313807                         BP PLC
# 10   2021-02-04  424B5   1173204                 Cinedigm Corp.
# 11   2021-02-04  424B5    771999  DOCUMENT SECURITY SYSTEMS INC
# 12   2021-02-04  424B5   1082038                    DURECT CORP
# 13   2021-02-04  424B5   1746466                Equillium, Inc.
# 14   2021-02-04  424B5   1713832                   HyreCar Inc.
# 15   2021-02-04  424B5    728387                   Isoray, Inc.
# 17   2021-02-04  424B5   1659617        Moleculin Biotech, Inc.
# 18   2021-02-04  424B5   1642380                  OncoCyte Corp
# 19   2021-02-04  424B5   1474098        Pebblebrook Hotel Trust
# 24   2021-02-04  424B5   1625101        Pulse Biosciences, Inc.
# 25   2021-02-04  424B5   1503274                 Quanterix Corp
# 26   2021-02-04  424B5   1697851            Rekor Systems, Inc.
# 27   2021-02-04  424B5    894158      Synthetic Biologics, Inc.
# 29   2021-02-04  424B5   1021162              TRIUMPH GROUP INC
# 31   2021-02-04  424B5   1163302       UNITED STATES STEEL CORP
# 32   2021-02-04  424B5   1375205                  UR-ENERGY INC
#
#                                                  Text Ticker Date Filed_y  \
# 0                                                  NA   ARGX   2021-02-04
# 1   You should consider carefully the risks descri...   ARQT   2021-02-04
# 2   Before you invest in the debentures, you shoul...    WRB   2021-02-04
# 9   Investing in the securities offered using this...     BP   2021-02-04
# 10  Before you invest in shares of our ClassA comm...   CIDM   2021-02-04
# 11  Ourbusiness is influenced by many factors that...    DSS   2021-02-04
# 12  Before you invest in our common stock, in addi...   DRRX   2021-02-04
# 13  Investing in our securities involves a high de...     EQ   2021-02-04
# 14  Investing in ourcommon stock involves a high d...   HYRE   2021-02-04
# 15  Investinginoursecuritiesinvolvesahighdegreeofr...    ISR   2021-02-04
# 17  An investment in our common stock involves ris...   MBRX   2021-02-04
# 18  Investingin our securities involves a high deg...    OCX   2021-02-04
# 19                                                 NA    PEB   2021-02-04
# 24  Investing in our common stock involves a high ...   PLSE   2021-02-04
# 25                                                 NA   QTRX   2021-02-04
# 26  Investing in our common stock involves a high ...   REKR   2021-02-04
# 27  Investing in our common stock involvesa high d...    SYN   2021-02-04
# 29  Investing in our common stock involves a high ...    TGI   2021-02-04
# 31                                                 NA      X   2021-02-04
# 32  An investment inour securities involves a high...    URG   2021-02-04
#
#     Previous Close   Next Open
# 0       362.440002  370.500000
# 1        34.630001   35.500000
# 2        63.599998   65.360001
# 9        21.270000   21.000000
# 10        1.630000    1.940000
# 11        4.380000    3.020000
# 12        2.870000    2.570000
# 13        6.620000    7.880000
# 14       15.620000   14.990000
# 15        1.890000    1.600000
# 17        4.680000    4.975000
# 18        5.350000    5.630000
# 19       19.969999   19.650000
# 24       36.619999   41.139999
# 25       72.459999   79.800003
# 26       14.770000   13.400000
# 27        0.830000    0.830000
# 29       13.430000   14.040000
# 31       16.260000   16.650000
# 32        0.920000    0.920000
